# %% [markdown]
# <a href="https://www.kaggle.com/code/alirezaatashnejad/detecting-happy-and-sad-faces-with-tensorflow?scriptVersionId=130103623" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="background-color:#FFFFF; padding:20px;">
#     <Center><h1 style="color:#FF7F50;">Image Classification for Sad and Happy Faces</h1></center>
# </div>

# %% [markdown]
# <div style="background-color:#FCE5CD; padding:20px;">
# <p style="color:#FF7F50;"><strong>Project Overview</strong></p>
# <p>The objective of this project is to create a model that can automatically detect and classify sad and happy faces in images. By training a deep learning model using a dataset of labeled facial expressions, we can teach the model to recognize patterns and features indicative of different emotions. The model will be built using popular deep learning frameworks such as TensorFlow, Keras, or PyTorch, which provide powerful tools for image classification tasks.</p>
# </div>

# %% [markdown]
# <div style="background-color:#FFF3B0; padding:20px;">
# <p style="color:#FF7F50;"><strong>Dataset</strong></p>
# <p>To train our image classification model, we will utilize a carefully curated dataset consisting of labeled images containing sad and happy faces. The dataset will be preprocessed and split into training and testing sets to evaluate the model's performance accurately. Augmentation techniques may also be applied to increase the dataset's diversity and enhance the model's ability to generalize.</p>
# </div>

# %% [markdown]
# <div style="background-color:#D9EAD3; padding:20px;">
# <p style="color:#FF7F50;"><strong>Model Architecture</strong></p>
# <p>We will design a deep neural network architecture suitable for image classification tasks. This architecture may include various layers such as convolutional layers for feature extraction, pooling layers for downsampling, and fully connected layers for classification. The model will be trained using an appropriate loss function and optimized through gradient-based algorithms.</p>
# </div>

# %% [markdown]
# <div style="background-color:#D0E0E3; padding:20px;">
# <p style="color:#FF7F50;"><strong>Training and Evaluation</strong></p>
# <p>During the training phase, the model will iteratively learn from the labeled images in the training set. We will monitor its progress by evaluating its performance on the testing set and fine-tuning the model as needed. The accuracy and other evaluation metrics will be used to assess the model's effectiveness in classifying sad and happy faces.</p>
# </div>

# %% [markdown]
# <div style="background-color:#E5D0ED; padding:20px;">
# <p style="color:#FF7F50;"><strong>Deployment and Application</strong></p>
# <p>Once the model is trained and evaluated, we can deploy it to make predictions on unseen images. This could include real-time analysis of facial expressions in videos or integrating the model into applications that require emotion detection. By accurately classifying sad and happy faces, we can unlock various potential applications, including sentiment analysis, affective computing, and human-computer interaction.</p>
# </div>

# %% [markdown]
# <div style="background-color:#E2A9A9; padding:20px;">
# <p style="color:#FF7F50;"><strong>Conclusion</strong></p>
# <p>The project aims to demonstrate the power of deep learning in accurately classifying sad and happy faces in images. By leveraging the capabilities of deep neural networks, we can enable machines to interpret and understand human emotions more effectively. The project's outcome will provide valuable insights into the development of advanced image classification systems and their potential impact on various domains, including psychology, marketing, and user experience research.</p>
# </div>

# %% [markdown]
# <font color='blue'><h1>Image Classification for Sad and Happy Faces</h1></font>
#
# <font color='black'><h3>Installation:</h3></font>
#
# <p>The following code snippet demonstrates the initial setup and import of necessary libraries for the <b>"Image Classification for Sad and Happy Faces"</b> project. The required libraries include TensorFlow, Pandas, Matplotlib, OpenCV (cv2), Imghdr, OS, and NumPy.</p>
# <p><font color='purple'>TensorFlow</font> is a popular deep learning framework used for building and training neural networks. <font color='purple'>Pandas</font> is a powerful data manipulation library, while <font color='purple'>Matplotlib</font> is used for data visualization. <font color='purple'>OpenCV (cv2)</font> is employed for image processing tasks, and <font color='purple'>Imghdr</font> is used for determining the type of image file. <font color='purple'>OS</font> is used for file and directory operations, and <font color='purple'>NumPy</font> is used for numerical computations.</p>
# <p>These libraries provide the essential tools and functionalities needed to preprocess and analyze the image dataset, build a deep learning model, and visualize the results.</p>
# <p>Please note that the code snippet only showcases the import statements and sets the foundation for the subsequent steps involved in the image classification process.</p>

# %%
import tensorflow as tf
import pandas as pd
import matplotlib as mp
import cv2
import imghdr
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# <font color='#008080'><b>Loading Data</b></font>

# %%
data_dir = 'data'

# %% [markdown]
# In the code snippet above, the variable <font color='#008080'><b>data_dir</b></font> is assigned the value <font color='#800080'>'data'</font>. This represents the directory where the data for the image classification task is stored. The specific data directory may vary depending on your project setup.
#
# This step is crucial for <font color='#008080'><b>accessing and organizing</b></font> the dataset that will be used for <font color='#008080'><b>training and evaluating</b></font> the image classification model. The dataset may contain separate folders for different <font color='#008080'><b>classes or labels</b></font>, each containing the corresponding images. By specifying the <font color='#008080'><b>data_dir</b></font>, you can easily <font color='#008080'><b>access and process</b></font> the data for further <font color='#008080'><b>analysis and model training</b></font>

# %% [markdown]
# <font color='#008080'><b>Image Extensions</b></font>

# %%
image_exts = ['jpeg' , 'jpg' ,'bmp' , 'png']

# %% [markdown]
# The variable <font color='#008080'><b>image_exts</b></font> is a list that contains the file extensions for images. In this case, it includes <font color='#800080'>jpeg</font>, <font color='#800080'>jpg</font>, <font color='#800080'>bmp</font>, and <font color='#800080'>png</font> extensions. These extensions represent common image file formats.
#
# This list is useful for filtering and selecting image files from a given directory or dataset. By specifying these extensions, you can easily identify and process the image files that match the desired formats. It ensures that only images with the specified extensions are considered for further analysis or processing.

# %% [markdown]
# <font color='#008080'><b>Listing Directory Contents</b></font>

# %%
os.listdir('/kaggle/input/sad-and-happy-face-detection/data')
# Out:
# ['sad', 'happy']

# %% [markdown]
# The above code snippet uses the os.listdir() function to list the contents of the directory located at <font color='#0E6EB8'>'/kaggle/input/sad-and-happy-face-detection/data'</font>. This function returns a list of all the files and directories present in the specified directory.
#
# By calling <font color='#0E6EB8'>os.listdir()</font> on the given directory path, you can access and retrieve the names of all the files and subdirectories within it. This information can be helpful when you need to iterate over the files, perform file operations, or obtain specific file names for further processing or analysis.
#
# In this case, the code is used to retrieve the contents of the directory <font color='#0E6EB8'>'data'</font> within the <font color='#0E6EB8'>'sad-and-happy-face-detection'</font> dataset. The returned list will contain the names of all the files and directories present in that directory.

# %% [markdown]
# <font color='#008080'><b>Filtering Images by Extension</b></font>

# %%
data_dir = '/kaggle/input/sad-and-happy-face-detection/data' 
image_exts = ['jpeg','jpg', 'bmp', 'png']
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %% [markdown]
# The above code snippet demonstrates how to filter images by their extensions in a given directory.
#
# Here's how it works:
#
# The variable <font color="#FF00FF">data_dir</font> stores the path to the directory where the images are located.
# The list <font color="#FF00FF">image_exts</font> contains the desired image extensions, such as 'jpeg', 'jpg', 'bmp', and 'png'.
# The code iterates over each image class (subdirectory) within the <font color="#FF00FF">data_dir</font> directory using <font color="#FF00FF">os.listdir(data_dir)</font>.
# For each image class, it further iterates over each image within that class using <font color="#FF00FF">os.listdir(os.path.join(data_dir, image_class))</font>.
# The <font color="#FF00FF">image_path</font> variable is created by joining the <font color="#FF00FF">data_dir</font>, <font color="#FF00FF">image_class</font>, and <font color="#FF00FF">image</font> names.
# Inside the loop, the code attempts to read the image using <font color="#FF00FF">cv2.imread(image_path)</font>.
# The <font color="#FF00FF">imghdr.what(image_path)</font> function is used to determine the image's format.
# If the image's format (<font color="#FF00FF">tip</font>) is not found in the <font color="#FF00FF">image_exts</font> list, it indicates that the image is not in the desired extensions. In this case, a message is printed indicating that the image is not in the extension list, and the image file is removed using <font color="#FF00FF">os.remove(image_path)</font>.
# If any exceptions occur during the image processing, an error message is printed, and the code has the option to remove the image file as well.
# This code snippet helps ensure that only images with specified extensions are retained in the directory, allowing for cleaner and more focused data for further analysis or training.

# %% [markdown]
# <font color='#008080'><b>Creating Image Dataset</b></font>

# %%
data = tf.keras.utils.image_dataset_from_directory('/kaggle/input/sad-and-happy-face-detection/data')
# Out:
# Found 1988 files belonging to 2 classes.

# %% [markdown]
# The above code snippet demonstrates how to create an image dataset from a directory using the TensorFlow Keras library.
#
# Here's how it works:
#
# The <font color="#FF00FF">image_dataset_from_directory</font> function is a convenient utility provided by TensorFlow Keras for loading images from a directory and creating a labeled dataset.
# The function takes the path to the directory containing the images as input.
# TensorFlow Keras automatically infers the labels from the subdirectories in the provided directory, where each subdirectory represents a different class or category.
# The function reads the images, applies optional preprocessing (such as resizing and rescaling), and creates a labeled dataset object that can be used for training, validation, or testing.
# The resulting dataset object can be further processed or fed directly into a machine learning model for training or evaluation.
# By using the <font color="#FF00FF">image_dataset_from_directory</font> function, you can quickly and easily create an image dataset for your deep learning tasks, eliminating the need for manual data loading and preprocessing

# %% [markdown]
# <font color='#008080'><b>Creating Data Iterator</b></font>

# %%
data_iterator = data.as_numpy_iterator()

# %% [markdown]
# The above code snippet demonstrates how to create a data iterator from the image dataset using the as_numpy_iterator() method.
#
# Here's how it works:
#
# The <font color='#008080'><b>as_numpy_iterator()</b></font> method is called on the image dataset object, <font color='#008080'><b>data</b></font>.
# This method returns an iterator that allows you to iterate over the dataset and retrieve batches of data in the form of <font color='#008080'><b>NumPy arrays</b></font>.
# Each iteration of the iterator provides a batch of data, where each element in the batch represents an image along with its corresponding label.
# You can use this iterator to process the data in a loop, feed it into a machine learning model for training or evaluation, or perform any other required operations.
# By creating a data iterator, you can easily access and manipulate the image dataset in <font color='#008080'><b>NumPy array format</b></font>, enabling you to perform various data processing tasks and seamlessly integrate the dataset with your deep learning workflow.

# %% [markdown]
# <font color='#008080'><b>Getting a Batch of Data</b></font>

# %%
batch = data_iterator.next()

# %% [markdown]
# The above code snippet demonstrates how to retrieve a batch of data from the data iterator.
#
# Here's how it works:
#
# The <font color='#008080'><b>next()</b></font> method is called on the data iterator object, <font color='#008080'><b>data_iterator</b></font>.
# This method fetches the next batch of data from the iterator.
# The retrieved batch is typically represented as a tuple containing two elements: the input data (images) and the corresponding labels.
# You can assign this tuple to a variable, such as <font color='#008080'><b>batch</b></font>, to access the data and labels for further processing.
# By obtaining a batch of data, you can perform operations on a subset of the dataset at a time, enabling efficient training and evaluation of deep learning models. This iterative process allows you to handle large datasets without loading the entire dataset into memory at once.

# %% [markdown]
# <font color='#008080'><b>Displaying a Selection of Images</b></font>

# %%
fig, ax = plt.subplots(ncols=5, nrows=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:20]):
    ax[idx//5, idx%5].imshow(img.astype(int))
    ax[idx//5, idx%5].title.set_text(batch[1][idx])
    ax[idx//5, idx%5].axis('off')

# %% [markdown]
# The above code snippet demonstrates how to display a selection of images from the batch using matplotlib.
#
# Here's how it works:
#
# We create a subplot grid with 5 columns and 4 rows using <font color='#008080'><b>plt.subplots(ncols=5, nrows=4, figsize=(20,20))</b></font>. This will create a figure with 20 subplots, each representing an image.
# We iterate over the images in the batch using <font color='#008080'><b>enumerate(batch[0][:20])</b></font>. This will give us the index and the corresponding image for each iteration.
# For each image, we use <font color='#008080'><b>ax[idx//5, idx%5].imshow(img.astype(int))</b></font> to display the image on the corresponding subplot.
# We set the title of each subplot to the corresponding label using <font color='#008080'><b>ax[idx//5, idx%5].title.set_text(batch[1][idx])</b></font>.
# Finally, we use <font color='#008080'><b>ax[idx//5, idx%5].axis('off')</b></font> to turn off the axis ticks and labels for a cleaner display.
# This code snippet will display a grid of 20 images, with each image labeled according to the corresponding label in the batch. Adjust the number of columns and rows in the subplot grid as per your preference to display more or fewer images.

# %% [markdown]
# <font color='#008080'><b>Applying Normalization to Image Data</b></font>

# %%
data = data.map(lambda x,y: (x/255,y))

# %% [markdown]
# The code snippet above demonstrates how to normalize the data in the dataset.
#
# Here's what it does:
#
# The <font color='#008080'><b>map()</b></font> function is applied to the <font color='#008080'><b>data</b></font> dataset.
# A lambda function is defined to perform the normalization operation on each sample.
# The lambda function divides the image data (<font color='#008080'><b>x</b></font>) by 255, which scales the pixel values between 0 and 1.
# The tuple (<font color='#008080'><b>x / 255, y</b></font>) represents the normalized image data (<font color='#008080'><b>x</b></font>) and the corresponding labels (<font color='#008080'><b>y</b></font>).
# By normalizing the data, we ensure that all the pixel values are within a consistent range, which is important for training machine learning models. Normalization helps improve the model's convergence during training and enhances its ability to learn meaningful patterns from the data.

# %% [markdown]
# <font color='#008080'><b>Converting Data to Numpy Array</b></font>

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.57254905, 0.47843137, 0.30588236],
#           [0.57011336, 0.47599572, 0.30344668],
#           [0.57296264, 0.47884497, 0.30629596],
#           ...,
#           [0.7288603 , 0.61947   , 0.46246937],
#           [0.7363051 , 0.6265012 , 0.46963847],
#           [0.7411765 , 0.6313726 , 0.4745098 ]],
#
#          [[0.5759932 , 0.4818755 , 0.3093265 ],
#           [0.5725797 , 0.478462  , 0.305913  ],
#           [0.57415247, 0.48003477, 0.30748576],
#           ...,
#           [0.72762716, 0.61823684, 0.4612362 ],
#           [0.73583794, 0.626034  , 0.46917123],
#           [0.7399433 , 0.6301394 , 0.47327664]],
#
#          [[0.5819402 , 0.48782256, 0.31527355],
#           [0.57683825, 0.48272058, 0.31017157],
#           [0.5762068 , 0.4820892 , 0.30954018],
#           ...,
#           [0.72549784, 0.6161075 , 0.45910692],
#           [0.73503107, 0.62522715, 0.46836442],
#           [0.737814  , 0.6280101 , 0.47114736]],
#
#          ...,
#
# ...

# %% [markdown]
# The above code snippet demonstrates how to convert the data to a Numpy array format using the <font color='#008080'><b>as_numpy_iterator()</b></font> function.
#
# Here's how it works:
#
# The <font color='#008080'><b>as_numpy_iterator()</b></font> method is called on the <font color='#008080'><b>data</b></font> object.
# This method returns an iterator that provides access to the elements of the dataset as Numpy arrays.
# The <font color='#008080'><b>next()</b></font> function is used to fetch the next batch of data from the iterator.
# The retrieved batch is returned as a Numpy array.
# By converting the data to a Numpy array format, you can leverage the extensive capabilities of the Numpy library for efficient computation and manipulation of the data. Numpy arrays are widely used in machine learning and deep learning frameworks due to their versatility and optimized performance.

# %% [markdown]
# <font color='#008080'><b>Splitting the Data into Train, Validation, and Test Sets</b></font>

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %% [markdown]
# The above code snippet showcases how to split the data into train, validation, and test sets based on the specified proportions.
#
# Here's how it works:
#
# The length of the data is calculated using the <font color='#008080'><b>len()</b></font> function, representing the total number of samples in the dataset.
# The train size is determined by multiplying the length of the data by 0.7, indicating that 70% of the data will be allocated for training.
# The validation size is computed by multiplying the length of the data by 0.2, indicating that 20% of the data will be reserved for validation.
# The test size is obtained by multiplying the length of the data by 0.1, indicating that 10% of the data will be used for testing.
# By splitting the data into different sets, you can effectively evaluate the performance of your deep learning model on unseen data and fine-tune its parameters during the training process. The train set is used to optimize the model's parameters, the validation set helps in monitoring the model's performance and preventing overfitting, while the test set provides an unbiased assessment of the final model's accuracy.

# %% [markdown]
# <font color='#008080'><b>Splitting the Data into Train, Validation, and Test Sets</b></font>

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# The above code snippet demonstrates how to split the data into train, validation, and test sets using the TensorFlow Dataset API.
#
# Here's how it works:
#
# The <font color='#008080'><b>take()</b></font> method is used to create a new dataset containing the specified number of elements from the beginning of the original dataset.
# The <font color='#008080'><b>skip()</b></font> method is used to create a new dataset that skips the specified number of elements from the beginning of the original dataset.
# By combining these methods, we can split the data into train, validation, and test sets based on the given proportions.
# The <font color='#008080'><b>train</b></font>, <font color='#008080'><b>val</b></font>, and <font color='#008080'><b>test</b></font> datasets can be used for training, validation, and testing of machine learning models respectively.
#
# Splitting the data into different sets is an important step in machine learning to ensure proper evaluation and generalization of models.

# %% [markdown]
# <font color='#008080'><b>Importing Required Modules</b></font>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D , Dense , Flatten , Dropout

# %% [markdown]
# The above code snippet demonstrates how to import the necessary modules from the TensorFlow Keras library for building a convolutional neural network (CNN) model.
#
# Here's what each module is used for:
#
# <font color='#008080'><b>Sequential</b></font>: This module is used to initialize a sequential model, which is a linear stack of layers. It allows us to build a deep learning model by adding layers one by one.
# <font color='#008080'><b>Conv2D</b></font>: This module is used to add a 2D convolutional layer to the model. It performs a convolution operation on the input data to extract relevant features.
# <font color='#008080'><b>MaxPooling2D</b></font>: This module is used to add a 2D max-pooling layer to the model. It reduces the spatial dimensions of the input data by taking the maximum value within each pooling window.
# <font color='#008080'><b>Dense</b></font>: This module is used to add a fully connected (dense) layer to the model. It connects every neuron in the previous layer to the neurons in the current layer.
# <font color='#008080'><b>Flatten</b></font>: This module is used to flatten the input data into a 1D array, which is required before passing it to the dense layers.
# <font color='#008080'><b>Dropout</b></font>: This module is used to add a dropout regularization layer to the model. It randomly drops a certain percentage of neurons during training to prevent overfitting.
#
# These modules provide the necessary building blocks for constructing a CNN model, which is commonly used for image classification tasks in deep learning.

# %% [markdown]
# <font color='#008080'><b>Creating a Sequential Model</b></font>

# %%
model = Sequential()

# %% [markdown]
# The above code snippet demonstrates how to create a sequential model using the <font color='#008080'><b>Sequential</b></font> class from TensorFlow Keras.
#
# Here's what it does:
#
# The <font color='#008080'><b>Sequential</b></font> function is called to initialize an empty sequential model.
# This model acts as a container for stacking layers.
# Once the model is created, you can add layers to it using the <font color='#008080'><b>add()</b></font> method.
# By building a sequential model, you can easily add layers one after another to create a deep learning architecture. The sequential nature of the model allows for a straightforward representation of the flow of data through the layers.

# %% [markdown]
# <font color='#008080'><b>Building the Convolutional Neural Network (CNN) Architecture</b></font>

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# The provided code snippet demonstrates the process of building a Convolutional Neural Network (CNN) architecture using the Sequential model from TensorFlow Keras. The architecture consists of several convolutional, pooling, and dense layers.
#
# Here's an explanation of each line of code:
#
# <font color='#008080'><b>model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))</b></font>
# This line adds a Conv2D layer to the model with 16 filters, a kernel size of (3,3), a stride of 1, and ReLU activation. It also specifies the input shape as (256,256,3), representing an input image with a height and width of 256 pixels and 3 color channels (RGB).
#
# <font color='#008080'><b>model.add(MaxPooling2D())</b></font>
# This line adds a MaxPooling2D layer to the model, which performs max pooling operation with default parameters.
#
# <font color='#008080'><b>model.add(Conv2D(32, (3,3), 1, activation='relu'))</b></font>
# This line adds another Conv2D layer with 32 filters, a kernel size of (3,3), a stride of 1, and ReLU activation.
#
# <font color='#008080'><b>model.add(MaxPooling2D())</b></font>
# This line adds another MaxPooling2D layer.
#
# <font color='#008080'><b>model.add(Conv2D(16, (3,3), 1, activation='relu'))</b></font>
# This line adds another Conv2D layer with 16 filters, a kernel size of (3,3), a stride of 1, and ReLU activation.
#
# <font color='#008080'><b>model.add(MaxPooling2D())</b></font>
# This line adds another MaxPooling2D layer.
#
# <font color='#008080'><b>model.add(Flatten())</b></font>
# This line adds a Flatten layer to convert the 2D feature maps into a 1D feature vector.
#
# <font color='#008080'><b>model.add(Dense(256, activation='relu'))</b></font>
# This line adds a Dense layer with 256 units and ReLU activation.
#
# <font color='#008080'><b>model.add(Dense(1, activation='sigmoid'))</b></font>
# This line adds the final Dense layer with 1 unit and sigmoid activation, representing the output layer for binary classification.
#
# By stacking these layers in a sequential manner, you create a deep learning architecture capable of learning hierarchical features from input images and making predictions.

# %% [markdown]
# <font color='#008080'><b>Compiling the Model</b></font>

# %%
model.compile('adam',loss = tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# The provided code snippet demonstrates how to compile the model using the <font color='#008080'><b>compile()</b></font> function in TensorFlow Keras. This step is crucial before training the model as it configures the model for the training process.
#
# Here's an explanation of the code:
#
# <font color='#008080'><b>model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])</b></font>
#
# This line of code compiles the model using the Adam optimizer as the optimizer function. The Adam optimizer is a popular choice for training deep learning models as it combines the advantages of two other optimization methods: AdaGrad and RMSProp.
#
# The <font color='#008080'><b>loss=tf.losses.BinaryCrossentropy()</b></font> argument specifies the loss function to be used during training. In this case, the BinaryCrossentropy loss function is chosen, which is commonly used for binary classification tasks.
#
# The <font color='#008080'><b>metrics=['accuracy']</b></font> argument specifies the evaluation metric to be used during training. In this case, the accuracy metric is chosen, which measures the percentage of correctly classified samples.
#
# By compiling the model with the appropriate optimizer, loss function, and evaluation metric, the model is prepared for the training process.

# %% [markdown]
# <font color='#008080'><b>Model Summary</b></font>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# ...
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code snippet <font color='#008080'><b>model.summary()</b></font> provides a concise summary of the model's architecture and parameters. It gives an overview of the number of parameters in each layer and the total number of trainable parameters in the model.
#
# Here's what the code does:
#
# <font color='#008080'><b>model.summary()</b></font>
#
# When called, this function displays a summary of the model's layers, their output shapes, and the number of parameters associated with each layer. It provides valuable information about the model's structure, including the input and output shapes of each layer and the number of parameters that will be learned during training.
#
# By inspecting the model summary, you can verify the architecture of your model, ensure that the number of parameters aligns with your expectations, and identify any potential issues with the layer configurations.
#
# Understanding the model summary is crucial for debugging and optimizing the model architecture, as it provides insights into the composition and complexity of the model.

# %% [markdown]
# <font color='#008080'><b>Setting up Logging Directory</b></font>

# %%
logdir = 'logs'

# %% [markdown]
# The code snippet <font color='#008080'><b>logdir = 'logs'</b></font> sets up a logging directory to store the logs generated during the training process.
#
# Here's what it does:
#
# The variable <font color='#008080'><b>logdir</b></font> is assigned the value 'logs'.
# This string represents the path or directory where the logs will be saved.
# By specifying a logging directory, you can store various logs related to the model, such as training progress, metrics, and visualizations. This allows you to review and analyze the model's performance during and after the training process.
#
# Setting up a logging directory is essential for keeping track of the model's progress, monitoring performance, and making informed decisions about model improvements or adjustments.

# %% [markdown]
# <font color='#008080'><b>Setting up TensorBoard Callback</b></font>

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %% [markdown]
# The code snippet <font color='#008080'><b>tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)</b></font> sets up a TensorBoard callback for logging and visualization purposes during the training process.
#
# Here's what it does:
#
# The <font color='#008080'><b>tf.keras.callbacks.TensorBoard()</b></font> function is called to create a TensorBoard callback object.
# The <font color='#008080'><b>log_dir</b></font> parameter is set to the specified <font color='#008080'><b>logdir</b></font> path, which represents the directory where the logs will be saved.
# The TensorBoard callback allows you to visualize and analyze various aspects of the model's performance, such as training and validation metrics, loss curves, and histograms of model parameters. It provides interactive and intuitive visualizations to gain insights into the model's behavior and make data-driven decisions for optimization.
#
# By setting up a TensorBoard callback, you can leverage the power of visualizations to monitor and evaluate your model's training progress in real-time.

# %% [markdown]
# <font color='#008080'><b>Training the Model</b></font>

# %%
hist = model.fit(train,epochs=30,validation_data=val,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 44/44 [==============================] - 45s 980ms/step - loss: 0.7014 - accuracy: 0.5334 - val_loss: 0.6621 - val_accuracy: 0.6198
# Epoch 2/30
# 44/44 [==============================] - 43s 961ms/step - loss: 0.6653 - accuracy: 0.5888 - val_loss: 0.6398 - val_accuracy: 0.6120
# Epoch 3/30
# 44/44 [==============================] - 40s 891ms/step - loss: 0.6524 - accuracy: 0.6229 - val_loss: 0.6227 - val_accuracy: 0.6484
# Epoch 4/30
# 44/44 [==============================] - 40s 884ms/step - loss: 0.6158 - accuracy: 0.6641 - val_loss: 0.6247 - val_accuracy: 0.6432
# Epoch 5/30
# 44/44 [==============================] - 40s 883ms/step - loss: 0.5609 - accuracy: 0.7038 - val_loss: 0.6003 - val_accuracy: 0.6484
# Epoch 6/30
# 44/44 [==============================] - 40s 890ms/step - loss: 0.4709 - accuracy: 0.7734 - val_loss: 0.6270 - val_accuracy: 0.7031
# Epoch 7/30
# ...

# %% [markdown]
# The code snippet <font color='#008080'><b>hist = model.fit(train, epochs=30, validation_data=val, callbacks=[tensorboard_callback])</b></font> trains the model using the provided training data, with additional validation and TensorBoard callback.
#
# Here's what it does:
#
# The <font color='#008080'><b>fit()</b></font> function is called on the model object to train the model.
# The <font color='#008080'><b>train</b></font> dataset is passed as the training data.
# The <font color='#008080'><b>epochs</b></font> parameter is set to 30, specifying the number of times the entire dataset will be passed through the model during training.
# The <font color='#008080'><b>validation_data</b></font> parameter is set to the <font color='#008080'><b>val</b></font> dataset, which will be used for validation during training.
# The <font color='#008080'><b>callbacks</b></font> parameter is set to include the <font color='#008080'><b>tensorboard_callback</b></font>, which enables TensorBoard logging during training.
# The <font color='#008080'><b>fit()</b></font> function performs the training process, updating the model's parameters based on the provided data and optimizing the defined loss function.
# The training progress, including training and validation metrics, loss curves, and other relevant information, will be logged to TensorBoard for visualization and analysis.
#
# By calling the <font color='#008080'><b>fit()</b></font> function with the appropriate parameters and including the TensorBoard callback, you can train your model and monitor its performance using the visualizations provided by TensorBoard.

# %% [markdown]
# <font color='#008080'><b>Plotting Loss</b></font>

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color = 'teal', label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# The code snippet <font color='#008080'><b>fig = plt.figure()
# plt.plot(hist.history['loss'], color='teal', label='loss')
# plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
# fig.suptitle('Loss', fontsize=20)
# plt.legend(loc="upper left")
# plt.show()</b></font> generates a plot to visualize the loss during training and validation.
#
# Here's how it works:
#
# A figure object <font color='#008080'><b>fig</b></font> is created to hold the plot.
# The training loss values from the <font color='#008080'><b>hist</b></font> object's history are plotted using <font color='#008080'><b>plt.plot()</b></font> with the color set to teal and labeled as 'loss'.
# The validation loss values from the <font color='#008080'><b>hist</b></font> object's history are plotted using <font color='#008080'><b>plt.plot()</b></font> with the color set to orange and labeled as 'val_loss'.
# The title of the plot is set using <font color='#008080'><b>fig.suptitle()</b></font> to display 'Loss' with a font size of 20.
# The legend is displayed in the upper left corner using <font color='#008080'><b>plt.legend()</b></font>.
# The plot is shown using <font color='#008080'><b>plt.show()</b></font>.
# By plotting the loss values, you can visually analyze the performance of your model during training and identify any trends or patterns in the training and validation loss. This can help you assess the effectiveness of your model and make adjustments if needed.

# %% [markdown]
# <font color='#008080'><b>Plotting Accuracy</b></font>

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'] , color ='teal' , label ='accuracy')
plt.plot(hist.history['val_accuracy'], color ='orange' , label = 'val_accuracy')
fig.suptitle('Accuracy' , fontsize =20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# The code snippet <font color='#008080'><b>fig = plt.figure()
# plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
# plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
# fig.suptitle('Accuracy', fontsize=20)
# plt.legend(loc="upper left")
# plt.show()</b></font> generates a plot to visualize the accuracy during training and validation.
#
# Here's how it works:
#
# A figure object <font color='#008080'><b>fig</b></font> is created to hold the plot.
# The training accuracy values from the <font color='#008080'><b>hist</b></font> object's history are plotted using <font color='#008080'><b>plt.plot()</b></font> with the color set to teal and labeled as 'accuracy'.
# The validation accuracy values from the <font color='#008080'><b>hist</b></font> object's history are plotted using <font color='#008080'><b>plt.plot()</b></font> with the color set to orange and labeled as 'val_accuracy'.
# The title of the plot is set using <font color='#008080'><b>fig.suptitle()</b></font> to display 'Accuracy' with a font size of 20.
# The legend is displayed in the upper left corner using <font color='#008080'><b>plt.legend()</b></font>.
# The plot is shown using <font color='#008080'><b>plt.show()</b></font>.
# By plotting the accuracy values, you can visually analyze the performance of your model during training and validation. This can help you understand how well your model is learning and improving over time.

# %% [markdown]
# <font color='#008080'><b>Importing Metrics</b></font>

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %% [markdown]
# The code snippet <font color='#008080'><b>from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy</b></font> imports the necessary metrics from TensorFlow Keras for evaluating model performance.
#
# Here's what it does:
#
# The <font color='#008080'><b>from</b></font> keyword is used to specify the module or package to import from.
# The module <font color='#008080'><b>tensorflow.keras.metrics</b></font> is imported.
# The metrics <font color='#008080'><b>Precision</b></font>, <font color='#008080'><b>Recall</b></font>, and <font color='#008080'><b>BinaryAccuracy</b></font> are specifically imported from the module.
# By importing these metrics, you can evaluate precision, recall, and binary accuracy during model training and evaluation. These metrics provide insights into different aspects of model performance, such as how well it correctly identifies positive instances (precision), how well it captures all positive instances (recall), and the overall accuracy in predicting binary classes.

# %% [markdown]
# <font color='#008080'><b>Initializing Metrics</b></font>

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %% [markdown]
# The code snippet <font color='#008080'><b>pre = Precision()</b></font>, <font color='#008080'><b>re = Recall()</b></font>, and <font color='#008080'><b>acc = BinaryAccuracy()</b></font> initializes the metrics for precision, recall, and binary accuracy.
#
# Here's what it does:
#
# The metrics <font color='#008080'><b>Precision()</b></font>, <font color='#008080'><b>Recall()</b></font>, and <font color='#008080'><b>BinaryAccuracy()</b></font> are called to create instances of these metrics.
# These instances, <font color='#008080'><b>pre</b></font>, <font color='#008080'><b>re</b></font>, and <font color='#008080'><b>acc</b></font>, are assigned to variables for later use.
# By initializing these metrics, you can use them to evaluate the precision, recall, and binary accuracy of your model predictions. These metrics are commonly used for classification tasks, where you want to assess the performance of the model in correctly predicting positive and negative instances.

# %% [markdown]
# <font color='#008080'><b>Evaluating Metrics</b></font>

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# ...
# 1/1 [==============================] - 0s 210ms/step

# %% [markdown]
# The code snippet demonstrates how to evaluate metrics on the test dataset using the trained model.
#
# Here's what it does:
#
# A loop is used to iterate over each batch in the test dataset, obtained using the <font color='#008080'><b>test.as_numpy_iterator()</b></font> function.
# For each batch, the input data <font color='#008080'><b>X</b></font> and corresponding labels <font color='#008080'><b>y</b></font> are extracted.
# The model's predictions <font color='#008080'><b>yhat</b></font> are obtained using the <font color='#008080'><b>model.predict()</b></font> function.
# The metrics <font color='#008080'><b>pre</b></font>, <font color='#008080'><b>re</b></font>, and <font color='#008080'><b>acc</b></font> are updated with the true labels <font color='#008080'><b>y</b></font> and predicted labels <font color='#008080'><b>yhat</b></font> using the <font color='#008080'><b>update_state()</b></font> function.
# By iterating over the test dataset and updating the metrics with the predictions, you can evaluate the precision, recall, and binary accuracy of the model on the test data. These metrics provide insights into the model's performance and its ability to classify sad and happy faces accurately.

# %% [markdown]
# <font color='#008080'><b>Printing Metric Results</b></font>

# %%
print(pre.result(), re.result(),acc.result())
# Out:
# tf.Tensor(0.75490195, shape=(), dtype=float32) tf.Tensor(0.6754386, shape=(), dtype=float32) tf.Tensor(0.6770833, shape=(), dtype=float32)

# %% [markdown]
# The code snippet you provided prints the current results of the precision, recall, and binary accuracy metrics.
#
# Here's what it does:
#
# It uses the <font color='#008080'><b>pre.result()</b></font> function to obtain the current value of the precision metric.
# It uses the <font color='#008080'><b>re.result()</b></font> function to obtain the current value of the recall metric.
# It uses the <font color='#008080'><b>acc.result()</b></font> function to obtain the current value of the binary accuracy metric.
# These metric values are then printed using the <font color='#008080'><b>print()</b></font> function.
# By printing the metric results, you can observe the performance of the model on the test dataset. The precision metric measures the model's ability to accurately classify positive predictions, the recall metric measures the model's ability to identify positive samples, and the binary accuracy metric measures the overall accuracy of the model's predictions.
#
# The printed results will provide insights into the model's performance on the test data in terms of precision, recall, and binary accuracy.

# %% [markdown]
# <font color='#008080'><b>Displaying an Image</b></font>

# %%
img = cv2.imread('/kaggle/input/sad-and-happy-face-detection/666.jpg')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The code snippet you provided displays an image using the OpenCV library and Matplotlib.
#
# Here's what it does:
#
# It uses the <font color='#008080'><b>cv2.imread()</b></font> function to read the image file located at '/kaggle/input/sad-and-happy-face-detection/666.jpg'.
# The image data is stored in the variable <font color='#008080'><b>img</b></font>.
# It uses the <font color='#008080'><b>plt.imshow()</b></font> function to display the image.
# Finally, it uses the <font color='#008080'><b>plt.show()</b></font> function to show the image in a Matplotlib plot.
# By executing this code snippet, you will be able to visualize the image stored at the specified file path. The image will be displayed in a plot using Matplotlib, allowing you to view its content.

# %% [markdown]
# <font color='#008080'><b>Resizing and Displaying an Image</b></font>

# %%
resize = tf.image.resize(img,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %% [markdown]
# The code snippet provided demonstrates how to resize and display an image using TensorFlow and Matplotlib.
#
# Here's what it does:
#
# It uses the <font color='#008080'><b>tf.image.resize()</b></font> function from TensorFlow to resize the image stored in the variable <font color='#008080'><b>img</b></font> to a size of (256, 256).
# The resized image is stored in the variable <font color='#008080'><b>resize</b></font>.
# It uses the <font color='#008080'><b>numpy()</b></font> method to convert the resized image to a NumPy array.
# The <font color='#008080'><b>astype(int)</b></font> function is used to convert the pixel values of the image to integers.
# It uses the <font color='#008080'><b>plt.imshow()</b></font> function to display the resized image.
# Finally, it uses the <font color='#008080'><b>plt.show()</b></font> function to show the resized image in a Matplotlib plot.
# By executing this code snippet, you will be able to resize the image to the specified dimensions and visualize the resized image using Matplotlib. This allows you to observe the changes in the image after resizing.

# %% [markdown]
# <font color='#008080'><b>Performing Inference on Resized Image</b></font>

# %%
yhat = model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 [==============================] - 0s 73ms/step

# %% [markdown]
# The provided code snippet demonstrates how to perform inference on a resized image using a trained model.
#
# Here's what it does:
#
# It uses the <font color='#008080'><b>np.expand_dims()</b></font> function to add an extra dimension to the resized image, converting it to the shape (1, 256, 256, 3). This is because the model expects a batch of images as input.
# The resized and expanded image is divided by 255 to normalize the pixel values between 0 and 1.
# It uses the <font color='#008080'><b>model.predict()</b></font> function to obtain the predicted output for the resized image. The resulting prediction is stored in the variable <font color='#008080'><b>yhat</b></font>.
# By executing this code snippet, you will obtain the predicted output for the resized image using the trained model.
# Note: Make sure to have the model trained and loaded before executing this code snippet.

# %% [markdown]
# <font color='#008080'><b>Predicted Output</b></font>

# %%
yhat
# Out:
# array([[0.7150497]], dtype=float32)

# %% [markdown]
# The code snippet above simply displays the variable <font color='#008080'><b>yhat</b></font>, which contains the predicted output for the resized image.
#
# By printing the variable <font color='#008080'><b>yhat</b></font>, you can observe the predicted output generated by the model. The predicted output can provide insights into how the model classifies the given image.
#
# Please note that the actual content of <font color='#008080'><b>yhat</b></font> will depend on the specific model and input image used for prediction.

# %% [markdown]
# <font color='#008080'><b>Predicted Class</b></font>

# %%
if yhat > 0.5:
    print (f'Predicted Class is Sad Face')
else:
    print (f'Predicted Class is Happy Face')
# Out:
# Predicted Class is Sad Face

# %% [markdown]
# The code snippet above checks the value of <font color='#008080'><b>yhat</b></font> and prints the predicted class based on a threshold of 0.5.
#
# If <font color='#008080'><b>yhat</b></font> is greater than 0.5, it is assumed that the predicted class is a sad face. Otherwise, it is assumed to be a happy face.
#
# This simple if-else statement helps in interpreting the predicted output of the model and provides a human-readable label for the predicted class.

# %% [markdown]
# <font color='#008080'><b>Loading a Saved Model</b></font>

# %%
from tensorflow.keras.models import load_model

# %% [markdown]
# To load a saved model, you can use the <font color='#008080'><b>load_model</b></font> function from TensorFlow Keras.
#
# Here's how you can do it:
#
# First, import the <font color='#008080'><b>load_model</b></font> function from <font color='#008080'><b>tensorflow.keras.models</b></font>.
# Next, call the <font color='#008080'><b>load_model</b></font> function and provide the path to the saved model as an argument. This will return the loaded model.
# You can now use the loaded model for inference, evaluation, or further training.
# By loading a saved model, you can reuse trained models without the need to retrain them from scratch. This is useful when you want to deploy a trained model in a production environment or continue training from a previously saved checkpoint.

# %% [markdown]
# <font color='#008080'><b>Saving a Trained Model</b></font>

# %%
model.save(os.path.join('imageclassifier.h5'))

# %% [markdown]
# To save a trained model, you can use the <font color='#008080'><b>save</b></font> method provided by the model object in TensorFlow Keras.
#
# Here's how you can do it:
#
# First, call the <font color='#008080'><b>save</b></font> method on your model object and provide the desired file path for saving the model.
# The model will be saved in the specified file path with the chosen file name and extension.
# By saving your trained model, you can easily load it later using the <font color='#008080'><b>load_model</b></font> function and reuse it for inference, evaluation, or further training. This allows you to persist your trained model and use it in different environments or share it with others.

# %% [markdown]
# <font color='#008080'><b>Loading a Saved Model</b></font>

# %%
new_model = load_model('imageclassifier.h5')

# %% [markdown]
# To load a saved model in TensorFlow Keras, you can use the <font color='#008080'><b>load_model</b></font> function.
#
# Here's how you can do it:
#
# Call the <font color='#008080'><b>load_model</b></font> function and provide the file path of the saved model as the argument.
# The function will load the model from the specified file path and return a new model object.
# You can assign this new model object to a variable, such as <font color='#008080'><b>new_model</b></font>, for further use.
# By loading a saved model, you can reuse the trained model for inference, evaluation, or further training without the need to retrain it from scratch. This allows you to save time and resources by leveraging the previously trained model.

# %% [markdown]
# <font color='#008080'><b>Using a Loaded Model for Predictions on New Images</b></font>

# %%
new_model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 [==============================] - 0s 80ms/step
# array([[0.7150497]], dtype=float32)

# %% [markdown]
# The following code snippet demonstrates how to use a loaded model to make predictions on new images.
#
# Here's what it does:
#
# First, we load the model using the <font color='#008080'><b>load_model()</b></font> function from TensorFlow Keras. The model is loaded from the file 'imageclassifier.h5'.
# Next, we preprocess the new image by resizing it using the <font color='#008080'><b>tf.image.resize()</b></font> function to match the input shape expected by the model.
# We use <font color='#008080'><b>np.expand_dims()</b></font> to add an extra dimension to the image array, as the model expects a batch of images as input. We also normalize the image by dividing it by 255 to bring the pixel values in the range of [0, 1].
# The preprocessed image is then passed to the <font color='#008080'><b>predict()</b></font> method of the loaded model to obtain the predicted class probabilities.
# Finally, we compare the predicted probability with a threshold (0.5 in this case) to determine the predicted class. If the probability is greater than 0.5, we classify it as a "Sad Face"; otherwise, it is classified as a "Happy Face".
# By using a loaded model, we can make predictions on new images without the need to retrain the model. This allows us to utilize the learned patterns and generalize the model's predictions to unseen data.
#
# Feel free to modify and experiment with this code to make predictions on your own images!

# %% [markdown]
# ## <font color='#008080'><b>Project Result and Usage</b></font>
#
# Congratulations on completing the project! You have successfully built an image classifier model that can classify images into "Sad" and "Happy" faces. Now, let's summarize the project's result and discuss how users can utilize the model to classify their own images.
#
# <font color='#008080'><b>Project Result:</b></font>
# Through the implementation of deep learning techniques, you have created a model that can accurately classify images based on emotional states. The model consists of convolutional and pooling layers for feature extraction, followed by dense layers for classification. It has been trained and evaluated on a dataset of "Sad" and "Happy" face images, achieving promising accuracy and performance.
#
# <font color='#008080'><b>Using the Model:</b></font>
# Users can take advantage of the trained model to classify their own images by following these steps:
#
# <font color='#008080'><b>Directory:</b></font> Users can place their images in a specific directory. The directory can be specified while executing the code.
#
# <font color='#008080'><b>Loading the Model:</b></font> The trained model can be loaded using the <code>load_model()</code> function from TensorFlow Keras. Ensure that the model file (e.g., 'imageclassifier.h5') is available in the appropriate location.
#
# <font color='#008080'><b>Preprocessing:</b></font> Users need to preprocess their images by resizing them to match the input shape expected by the model. They can use the <code>tf.image.resize()</code> function for resizing.
#
# <font color='#008080'><b>Predictions:</b></font> The preprocessed images can then be passed through the loaded model's <code>predict()</code> method to obtain the predicted class probabilities. By comparing the predicted probability with a threshold (e.g., 0.5), users can determine the predicted class.
#
# Users have the flexibility to change the images in the directory or upload new images to check the model's predictions. This allows them to explore the model's performance on their own datasets and analyze the emotional states depicted in the images.
#
# Remember to consider the requirements and dependencies of the project, such as the TensorFlow and Keras libraries, and ensure that the environment is set up properly to execute the code.
#
# With this model in hand, users can now easily classify the emotional states of faces in their own images and gain valuable insights from their visual data. <font color='#008080'><b>Happy classifying!</b></font>
# <font color='Black'><center><b>Alireza Atashnejad - Data Scientist</b></center></font>
